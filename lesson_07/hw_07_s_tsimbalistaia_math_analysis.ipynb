# %% [markdown]
# ## **Тема 7 "Производная функции одной переменной"**

# %% [markdown]
# 1. **Найти длину 𝑥 и ширину 𝑦 прямоугольника при заданном периметре 𝑃=144 cм, при которых данный прямоугольник имеет наибольшую площадь 𝑆.**

# %% [markdown]
# $P = 2(a+b)=144 см$
#
# $S= a*b$
#
# $a+b = \frac{144}{2} = 72$
#
# $b = 72 - a$
#
# $S = a * b  = a * (72 - a)$
#
# $S' = (a * (72 - a))' = (72a  -a^2)' = 72 - 2a$
#
# Чтобы найти критические точки функции площади, приравняем производную к нулю
#
# $72 - 2a = 0$
#
# $a = 36$
#
# В точке a=36 фукция S = a * (72 - a) имеет критическую точку. Нужно исследовать, является ли она экстремумом.
#
# При a = 1 72-2 = 70. Производная больше нуля
# При a=40 72 -80 = -8 Производная меньше нуля.
#
# a=36 является экстремумом, при котором функция S = a * (72 - a) принимает максимальное значение (так как знак проиводной меняется с + на -).
# S = a * (72 - a) = 36 * (72 - 36) = 1296 см2
#
# Найдем b:
#
# b = 72 - a = 36см.
#
# Ответ: длина 36 см, ширина 36 см.

# %% [markdown]
# 2. **Найти экстремумы функций, если они есть:**
#
# $1. y = |2x|$
#
# $y' = (|2x|)' = 2(|x|)' = \frac{2x}{|x|}$
#
# Критическая точка - это точка, в которой производная функции обращается в 0 или не существует.
#
# Производной не существует при x=0
#
# Найдем критические точки, в которых производная равна 0.
#
# $\frac{2x}{|x|} = 0$
#
# $2x = 0;            x=0$
# Также получается 0, который не является решением уравнения, так как идет деление на ноль.
# Получается функция имеет одну критическую точку х=0.
#
# Проверим, является ли 0 экстремумом.
#
# $y'(-1) = -2$
#
# $y'(1) = 2$
#
# Точка x=0 является экстремумом (минимумом) функции y = |2x|, так как производная, при переходе через нее с - на +.

# %% [markdown]
# $2. y = x^3$
#
# $y' = 3x^2$
#
# $3x^2 = 0; x=0$
#
# Получается функция имеет одну критическую точку х=0.
#
# Проверим, является ли 0 экстремумом.
#
# $y'(-1) = 3$
#
# $y'(1) = 3$
#
# Функция $y = x^3$ не имеет экстремумов, имеет одну критическую точку х=0 (перегиб функции).

# %% [markdown]
# $3. y = e^{3x}$
#
# $y' = (e^{3x})' = 3e^{3x}$
#
# $3e^{3x} = 0$  - невозможно при любом значении x. Функция не имеет критических точек, в том числе экстремумов
#
# График функции $3. y = e^{3x}$:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $3. y = x^3 - 5x$
#
# $y' = (x^3 - 5x)' = 3x^2 - 5$
#
# $3x^2 - 5 = 0$
#
# $x1 = \sqrt{1\frac{2}{3}};$ $x2 = -\sqrt{1\frac{2}{3}}$ - критические точки
#
# Исследуем на экстремумы:
#
# $y'(-2) = 7$
#
# $y'(-1) = -2$
#
# $y'(2) = 7$
#
# Получается точки $x1 = \sqrt{1\frac{2}{3}} (максимум);$ $x2 = -\sqrt{1\frac{2}{3}} (минимум)$ являются экстремумами функциями, так как при проходе через них производая меняет знак.
#
# График функции $y = x^3 - 5x$:

# %% [markdown]
# ![image.png](attachment:image.png)
