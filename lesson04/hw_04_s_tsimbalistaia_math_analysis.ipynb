# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## ***Тема “Предел функции”***

# %% [markdown]
# **1. Предложить пример функции, не имеющей предела в нуле и в бесконечностях.**

# %% [markdown]
# 1. Функция, вообще не имеющая предел как таковая. В частности y=sin(x).
#
# Функция sinx периодическая с периодом 2pi, следовательно, при неограниченном возрастании аргумента эта функция периодически пробегает все свои значения [-1; 1].
# ![image.png](attachment:image.png)
#
# 2. y= 1/x в нуле не определена и соответсвенно не имеет предела в нуле. Так как функция не является непрерывной, то она не имеет одного предела и на бесконченостях.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **2. Привести пример функции, не имеющей предела в точке, но определенной в ней.**

# %% [markdown]
# y = sign(x).
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Ясно, что в любой сколь угодно малой окрестности точки О найдутся числа, для которых значения функции равны как +1, так и -1 (для положительных и отрицательных значений аргумента соответственно). Следовательно, ни к какому общему пределу при произвольном стремлении аргумента к 0 значения функции приближаться не могут, так что предел данной функции в точке 0 не существует.
#
# Отметим, что для ненулевых значений а предел данной функции, очевидно, существует:
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# **3. Исследовать функцию $y = x^3 - x^2$ по плану:**
#
# **Область задания и область значений.**
#
# **Нули функции и их кратность.**
#
# **Отрезки знакопостоянства.**
#
# **Интервалы монотонности.**
#
# **Четность функции.**
#
# **Ограниченность.**
#
# **Периодичность.**

# %% [markdown]
# **Область задания и область значений.**
#
# Функция определена и имеет значения на всей числовой прямой.
#
# Построим график функции.

# %%
x = np.linspace(-100, 100, 1000)
y = x**3 - x**2
plt.plot(x, y)
ax = plt.gca()

# plot X - axis    
ax.axhline(y=0, color='k')

# plot Y - axis    
ax.axvline(x=0, color='k')
plt.show()

# %%
x = np.linspace(-1, 1.5, 1000)
y = x**3 - x**2
plt.plot(x, y)
ax = plt.gca()

# # plot X - axis    
ax.axhline(y=0, color='k')

# # plot Y - axis    
ax.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# **Нули функции и их кратность.**
# $$y = x^3 - x^2 = x^2(x - 1)$$
# x1 = 0 (кратность 2)
#
# x2 = 1 (кратность 1)

# %% [markdown]
# **Отрезки знакопостоянства.**

# %% [markdown]
# 1. $x \in (- \infty; 0)$ - отрицательная

# %%
x = -1
y = x**3 - x**2
y
# Out:
# -2

# %% [markdown]
# 2. $x \in (0; 1)$ - отрицательная

# %%
x = 0.5
y = x**3 - x**2
y
# Out:
# -0.125

# %% [markdown]
# 3. $x \in (1; \infty)$ - положительная

# %%
x = 2
y = x**3 - x**2
y
# Out:
# 4

# %% [markdown]
# **Интервалы монотонности.**
# $$y = x^3 - x^2 $$
# $$f(x)`= 3x^2 - 2x = x(3x-2)$$
# $$f(x)`= 0  \;при  \;x=0  \;и  \;x=\frac{2}{3}$$

# %%
#при x < 0 - функция возрастает
x = -1
g = 3 * x**2 - 2 * x
g
# Out:
# 5

# %%
#при 0 < x < 2/3 - функция убывает
x = 0.4
g = 3 * x**2 - 2 * x
g
# Out:
# -0.31999999999999995

# %%
#при 2/3 < x - функция возрастает
x = 5
g = 3 * x**2 - 2 * x
g
# Out:
# 65

# %% [markdown]
# Итого
#
# f(x) возрастает при  $x \in (- \infty; 0)\cup(\frac{2}{3}, \infty)$;
#
# f(x) убывает при  $x \in (0;\frac{2}{3})$;

# %% [markdown]
# **Четность функции.**
#
# Функция общего вида (не является ни четной, ни нечетной)

# %% [markdown]
# **Ограниченность.**
#
# Неограничена

# %% [markdown]
# **Периодичность.**
#
# Непериодическая

# %% [markdown]
# **4. Найти предел:**

# %% [markdown]
# ![4-1.jpg](attachment:4-1.jpg)

# %% [markdown]
# $\lim_{x \to 0} \frac{3x^3 - 2x^2}{4x^2} = \lim_{x \to 0} \frac {x^2(3x- 2)}{4x^2} = \lim_{x \to 0} \frac {3x- 2}{4}= \frac {-1}{2}$<br>
# $\lim_{x \to 0} \frac{\sqrt(1 + x) - 1}{\sqrt[3](1 + x) - 1} = \lim_{x \to 0} \frac{\sqrt(1 + x) - 1}{\sqrt[3](1 + x) - 1} * \frac{\sqrt(1 + x) + 1}{\sqrt(1 + x) + 1} * \frac{(\sqrt[3](1 + x))^2 + \sqrt[3](1 + x) + 1}{(\sqrt[3](1 + x))^2 + \sqrt[3](1 + x) + 1} = \lim_{x \to 0} \frac{1 + x - 1}{1 + x - 1} * \frac{(\sqrt[3](1 + x))^2 + \sqrt[3](1 + x) + 1}{\sqrt(1 + x) + 1} = \lim_{x \to 0} \frac{(\sqrt[3](1 + x))^2 + \sqrt[3](1 + x) + 1}{\sqrt(1 + x) + 1} = \frac{(\sqrt[3](1 + 0))^2 + \sqrt[3](1 + 0) + 1}{\sqrt(1 + 0) + 1} = \frac{3}{2} = 1\frac{1}{2}$<br>

# %% [markdown]
# ## ***Тема “Теоремы о пределах”***

# %% [markdown]
# **1. Найти предел:**

# %% [markdown]
# ![1-1.jpg](attachment:1-1.jpg)

# %% [markdown]
# Для решения используем первый замечательный предел:
# ![image.png](attachment:image.png)

# %% [markdown]
# $\lim_{x \to 0} \frac{sin(2x)}{4x} = \lim_{x \to 0} \frac{sin(2x)}{2 * 2x} =\frac {1}{2}$

# %% [markdown]
# $\lim_{x \to 0} \frac{x}{sin(x)} =\lim_{x \to 0} \frac{sin(x)}{x}  =1$
